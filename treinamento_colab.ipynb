# %% [markdown]
# # Treinamento do Campo Minado RL no Google Colab
#
# Este notebook configura o ambiente e treina a Inteligência Artificial na nuvem, sendo muito mais rápido do que rodar localmente.

# %%
# !git clone https://github.com/Carlos-Israel/Campo-Minado.git
# %cd Campo-Minado

# %%
# !pip install -r requirements.txt

# %%
# Rodar o script de treinamento completo (PPO, A2C e Optuna)
# !python campo_minado_rl.py

# %% [markdown]
# ## Dica de Ouro
# Após terminar, as pastas models/ e graficos/ estarão populadas aqui no ambiente virtual do Colab. Baixe esses arquivos e coloque-os na sua máquina local para rodar o isualizar_agente.py e ver a IA jogando!
